# %%
import pandas as pd


data = pd.read_csv('NYPD_Motor_Vehicle_Collisions.csv')

# %%
dataTrim = data.dropna(thresh=28)

# %%
dataTrim.sort_values(by=['BOROUGH'])
# Out:
#                DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 574267   09/06/2016  11:47          BRONX    10473  40.819878 -73.857770
# 901088   03/25/2015   3:30          BRONX    10469  40.874514 -73.857442
# 894145   04/07/2015   5:42          BRONX    10454  40.810053 -73.925144
# 190341   05/10/2018  11:25          BRONX    10452  40.831974 -73.923500
# 728182   01/04/2016   5:20          BRONX    10466  40.883861 -73.855885
# 728470   01/03/2016  16:22          BRONX    10454  40.808134 -73.916588
# 891679   04/12/2015  22:02          BRONX    10454  40.807187 -73.924280
# 434255   04/23/2017   5:30          BRONX    10468  40.862812 -73.907555
# 889830   04/15/2015  14:54          BRONX    10469  40.862738 -73.841767
# 204752   04/19/2018   5:39          BRONX    10466  40.894314 -73.860270
# 888334   04/18/2015   4:17          BRONX    10460  40.836771 -73.885964
# 887764   04/19/2015   5:38          BRONX    10452  40.843908 -73.924130
# ...

# %%
dataFinal = dataNew[dataNew.BOROUGH == 'MANHATTAN']

# %%
dataFinal.to_csv('CarCrashData.csv', sep=",")
