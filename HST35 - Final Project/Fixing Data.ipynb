# %%
import pandas as pd
import datetime

import numpy as np

df1 = pd.read_csv(open('/home/ryebyread/dev/HST-325/FinalProject/data.csv'), encoding='utf-8', engine='c')

# %%
df1 = df1.drop(['id_str'], axis=1)

# %%
df1 = df1[['text','Date','is_retweet']]

# %%
df1 = df1.dropna(axis=0, how='any')

# %%
def fixDate(row):
    try:
        rmTime = row['Date'].split(' ')[0]
        rmDash = rmTime.split('-')
        rmDash.reverse()
        if ''.join(rmDash) == '':
            row['Date']= None
        else:
            row['Date']= ''.join(rmDash)
        return row
    
    except:
        row['Date'] = None
        return row
#lambda row goes through every single row
df1 = df1.apply(lambda row: fixDate(row), axis=1)

# %%
df1['randNumCol'] = np.random.randint(1, 9000, df1.shape[0])

df1Real = df1.dropna(axis=0, how='any')

# %%
dateDups = df1Real.pivot_table(index=['Date'], aggfunc='size')

# %%
df1Real['ID'] = df1Real.apply( lambda row: dateDups.loc[row.loc['Date']], axis = 1)
# Out:
# /home/ryebyread/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
 df1Real.sort_values(by=['Date'])
# Out:
#                                                    text      Date is_retweet  \
# 2     RT @Reince: Happy New Year + God's blessings t...  20170101       TRUE
# 3     RT @EricTrump: 2016 was such an incredible yea...  20170101       TRUE
# 4     RT @DonaldJTrumpJr: Happy new year everyone. #...  20170101       TRUE
# 5     RT @IvankaTrump: 2016 has been one of the most...  20170101       TRUE
# 216   Hope you like my nomination of Judge Neil Gors...  20170102      FALSE
# 217   Everybody is arguing whether or not it is a BA...  20170102      FALSE
# 215   Join me live from the @WhiteHouse.https://t.co...  20170102      FALSE
# 214   Getting ready to deliver a VERY IMPORTANT DECI...  20170102      FALSE
# 369        #JointSession #MAGA🇺🇸https://t.co/RDO6Jt2pip  20170103      FALSE
# 368   Join me live at 9:00 P.M. #JointAddress https:...  20170103      FALSE
# 370                                          THANK YOU!  20170103      FALSE
# 517   RT @DanScavino: .@POTUS @realDonaldTrump signs...  20170104       TRUE
# 518   The failing @nytimes finally gets it - "In pla...  20170104      FALSE
# 519   ...use subsidies to buy health plans." In othe...  20170104      FALSE
# 520   Wow @FoxNews just reporting big news. Source: ...  20170104      FALSE
# 521   ..not associated with Russia. Trump team spied...  20170104      FALSE
# 522   Thank you @JCLayfield -- will get even better ...  20170104      FALSE
# 516   It is the same Fake News Media that said there...  20170104      FALSE
# 515   When will Sleepy Eyes Chuck Todd and @NBCNews ...  20170104      FALSE
# 825   Join me live at the @WhiteHouse.➡️https://t.co...  20170106      FALSE
# 824   The big story is the "unmasking and surveillan...  20170106      FALSE
# 823   I will be announcing my decision on Paris Acco...  20170106      FALSE
# 826   My job as President is to do everything within...  20170106      FALSE
# 1036  Numerous states are refusing to give informati...  20170107      FALSE
# 1037  I am extremely pleased to see that @CNN has fi...  20170107      FALSE
# 1038  Crazy Joe Scarborough and dumb as a rock Mika ...  20170107      FALSE
# 1039  Weekly Address🇺🇸 #KatesLaw#NoSanctuaryForCrimi...  20170107      FALSE
# 1040  Getting rdy to leave for tonight's Celebrate F...  20170107      FALSE
# 1042  ....the 2016 election with interviews speeches...  20170107      FALSE
# 1043  I am thinking about changing the name #FakeNew...  20170107      FALSE
